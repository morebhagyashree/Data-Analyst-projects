# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <b>Task 1: Load the movie dataset in the python notebook.display the numbers of rows and columns in the dataset. Display the title and genres of the first 50 movies from the dataset.

# %%
df=pd.read_csv("DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
row,col=df.shape
print("rows : ",row)
print("columns : ",col)
# Out:
# rows :  4803
# columns :  20

# %%
import json

# %%
def safe_json_parse(json_str):
    try:
        return json.loads(json_str.replace("'", "\""))
    except json.JSONDecodeError:
        return []

# Convert the 'production_companies' column values to strings
df['production_companies'] = df['production_companies'].astype(str)

# Create a new column 'production_companies1' by joining 'production_companies' values with commas
df['production_companies1'] = df['production_companies'].apply(lambda x: ', '.join([company['name'] for company in safe_json_parse(x)]))

# Display the DataFrame with the new 'production_companies1' column
print(df[['original_title', 'production_companies1']])
# Out:
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                   production_companies1
# 0     Ingenious Film Partners, Twentieth Century Fox...
# 1     Walt Disney Pictures, Jerry Bruckheimer Films,...
# 2                        Columbia Pictures, Danjaq, B24
# 3     Legendary Pictures, Warner Bros., DC Entertain...
# 4                                  Walt Disney Pictures
# ...                                                 ...
# ...

# %%
# Create a new column 'Genres' with concatenated genre names
df['Genres1'] = df['genres'].apply(lambda x: ', '.join([genre['name'] for genre in json.loads(x.replace("'", "\""))]))

# Display the DataFrame with the 'Genres' column
print(df[['original_title', 'Genres1']])
# Out:
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                           Genres1
# 0     Action, Adventure, Fantasy, Science Fiction
# 1                      Adventure, Fantasy, Action
# 2                        Action, Adventure, Crime
# 3                  Action, Crime, Drama, Thriller
# 4              Action, Adventure, Science Fiction
# ...                                           ...
# ...

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df.dtypes
# Out:
# budget                     int64
# genres                    object
# homepage                  object
# id                         int64
# keywords                  object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# production_companies      object
# production_countries      object
# release_date              object
# revenue                    int64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# vote_average             float64
# vote_count                 int64
# production_companies1     object
# Genres1                   object
# dtype: object

# %%
first_50_movies = df[['title', 'Genres1']].head(50)
first_50_movies
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# <b>Task 2: Identify the columns that have null values and perform the null treatment.

# %%
df.isnull().sum()
# Out:
# budget                      0
# genres                      0
# homepage                 3091
# id                          0
# keywords                    0
# original_language           0
# original_title              0
# overview                    3
# popularity                  0
# production_companies        0
# production_countries        0
# release_date                1
# revenue                     0
# runtime                     2
# spoken_languages            0
# status                      0
# tagline                   844
# title                       0
# vote_average                0
# vote_count                  0
# production_companies1       0
# Genres1                     0
# dtype: int64

# %%
df.dtypes
# Out:
# budget                     int64
# genres                    object
# homepage                  object
# id                         int64
# keywords                  object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# production_companies      object
# production_countries      object
# release_date              object
# revenue                    int64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# vote_average             float64
# vote_count                 int64
# production_companies1     object
# Genres1                   object
# dtype: object

# %%
df['homepage'].fillna('UNKNOWN',inplace=True)
df['tagline'].fillna('UNKNOWN',inplace=True)

# %%
df['overview'].fillna('UNKNOWN',inplace=True)

# %%
df.dropna(subset=['release_date'], inplace=True)

# %%
df.dropna(subset=['runtime'],inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# <b>Task 3: Display the movie categories that have a budget greater than $220000

# %%
filtered_movies = df[df['budget'] > 220000]
filtered_movies['Genres1']
# Out:
# 0       Action, Adventure, Fantasy, Science Fiction
# 1                        Adventure, Fantasy, Action
# 2                          Action, Adventure, Crime
# 3                    Action, Crime, Drama, Thriller
# 4                Action, Adventure, Science Fiction
#                            ...
# 4680                        Crime, Horror, Thriller
# 4682                                         Horror
# 4720                                          Drama
# 4758                      Thriller, Science Fiction
# 4770                                  Drama, Comedy
# Name: Genres1, Length: 3683, dtype: object

# %% [markdown]
# <b>Task 4: Display the movie categories where the revenue is greater than $961000000

# %%
p=df[df['revenue']>961000000]
p['Genres1']
# Out:
# 0       Action, Adventure, Fantasy, Science Fiction
# 3                    Action, Crime, Drama, Thriller
# 7                Action, Adventure, Science Fiction
# 12                       Adventure, Fantasy, Action
# 16               Science Fiction, Action, Adventure
# 17                       Adventure, Action, Fantasy
# 25                         Drama, Romance, Thriller
# 26               Adventure, Action, Science Fiction
# 28     Action, Adventure, Science Fiction, Thriller
# 29                      Action, Adventure, Thriller
# 31               Action, Adventure, Science Fiction
# 32                       Family, Fantasy, Adventure
# 36               Science Fiction, Action, Adventure
# 42                        Animation, Family, Comedy
# 44                                           Action
# 52               Action, Science Fiction, Adventure
# 65                   Drama, Action, Crime, Thriller
# 78                Family, Adventure, Drama, Fantasy
# ...

# %% [markdown]
# <b>Task 5:In the dataset there are some movies for which the budget and revenue columns have the value 0, which mean unknown values.Remove the rows with value 0 from both the buddget and revenue columns.

# %%
new_df=df[(df['budget']!=0) & (df['revenue']!=0)]
new_df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# <b>Task 6:List the top 10 movies with the highest revenues and the top 10 movies with the least budget.

# %%
m=new_df.sort_values(by='revenue',ascending=False)[:10]
m[['title','revenue']]
# Out:
#                           title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495

# %%
q=new_df.sort_values('budget',ascending=True)[:10]
q[['title','budget']]
# Out:
#                    title  budget
# 4238        Modern Times       1
# 3611  A Farewell to Arms       4
# 3372        Split Second       7
# 3419        Bran Nue Dae       7
# 4608        The Prophecy       8
# 3131   Of Horses and Men      10
# 3137           Nurse 3-D      10
# 2933            F.I.S.T.      11
# 1912      Angela's Ashes      25
# 1771      The 51st State      28

# %% [markdown]
# <b>Task 7: How are popularities of movies related with the movie budgets?Are they correlated or totally uncorrelated with each other?write the interpretation of your analysis.

# %%
d1=round(new_df['budget'].corr(new_df['popularity']),2)
d1
# Out:
# 0.43

# %%
plt.xlabel("budget")
plt.ylabel("popularity")
plt.title("co-relation between budget and popularity")
plt.scatter(new_df['budget'],new_df['popularity'],label='r='+str(d1))
plt.legend()
plt.show()

# %% [markdown]
# <b>Interpretation: Movie budgets and popularity are correlated, but not perfectly.there is a moderate positive correlation (0.43) between movie budgets and movie popularity. This suggests that, on average, movies with higher budgets tend to be more popular. However, other factors also play a significant role in a movie's success, and budget alone does not guarantee popularity.

# %% [markdown]
# <b>Task 8: Identify and display the names of all production companies along with the number of times they appears in the dataset.

# %%
production_company_counts = new_df['production_companies1'].str.split(', ').explode().value_counts()

# Display the production company names and their counts
print(production_company_counts)
# Out:
# Warner Bros.                              277
# Universal Pictures                        272
# Paramount Pictures                        242
# Twentieth Century Fox Film Corporation    190
# Columbia Pictures                         167
#                                          ...
# Southpaw Entertainment                      1
# Prana Studios                               1
# Midwinter Productions Inc.                  1
# Playtone Production                         1
# Daiei Studios                               1
# Name: production_companies1, Length: 3484, dtype: int64

# %% [markdown]
# <b>Task 9: Display the names of the top 25 production companies based on the number of movies by have produced in descending order of the number of movies produced.

# %%
production_companies_series = new_df['production_companies1'].str.split(', ').explode()
production_company_counts = production_companies_series.value_counts()
# Display the top 25 production companies
top_25_production_companies = production_company_counts.head(25)
print(top_25_production_companies)
# Out:
# Warner Bros.                              277
# Universal Pictures                        272
# Paramount Pictures                        242
# Twentieth Century Fox Film Corporation    190
# Columbia Pictures                         167
# New Line Cinema                           138
# Relativity Media                          100
# Walt Disney Pictures                       95
# Metro-Goldwyn-Mayer (MGM)                  91
# Touchstone Pictures                        91
#                                            90
# Columbia Pictures Corporation              85
# Village Roadshow Pictures                  71
# DreamWorks SKG                             67
# Miramax Films                              66
# United Artists                             64
# Regency Enterprises                        59
# Dune Entertainment                         51
# TriStar Pictures                           50
# Summit Entertainment                       49
# ...

# %% [markdown]
# <b>Task 10:sort the data in descending order based on revenue and filter the top 500 movies. find the measures of central tendancy for the following columns using the filter data.1.budget, revenue,runtime and perform outlier analysis for above 3 columns using box plots.

# %%
df_rev=new_df.sort_values(by=['revenue'], ascending=False)[:500]
df_rev
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44    190000000                     [{"id": 28, "name": "Action"}]
# ...         ...                                                ...
# 397    85000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 1744   30000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 698    70000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 717    60000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 714    65000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
#
#                                homepage      id  \
# 0           http://www.avatarmovie.com/   19995
# 25          http://www.titanicmovie.com     597
# ...

# %%
cen_ten=pd.DataFrame()
cen_ten['central tendancy']=['Mean','Median','Mode']
cen_ten
# Out:
#   central tendancy
# 0             Mean
# 1           Median
# 2             Mode

# %%
bud=[]
bud.append(df_rev['budget'].mean())
bud.append(df_rev['budget'].median())
bud.append(df_rev['budget'].mode()[0])
cen_ten['Budget']=bud
cen_ten
# Out:
#   central tendancy       Budget
# 0             Mean  103193736.0
# 1           Median   95000000.0
# 2             Mode  150000000.0

# %%
rev=[]
rev.append(df_rev['revenue'].mean())
rev.append(df_rev['revenue'].median())
rev.append(df_rev['revenue'].mode()[0])
cen_ten['revenue']=rev
cen_ten
# Out:
#   central tendancy       Budget       revenue
# 0             Mean  103193736.0  4.585776e+08
# 1           Median   95000000.0  3.630016e+08
# 2             Mode  150000000.0  2.177643e+08

# %%
run=[]
run.append(df_rev['runtime'].mean())
run.append(df_rev['runtime'].median())
run.append(df_rev['runtime'].mode()[0])
cen_ten['runtime']=run
cen_ten
# Out:
#   central tendancy       Budget       revenue  runtime
# 0             Mean  103193736.0  4.585776e+08   118.72
# 1           Median   95000000.0  3.630016e+08   116.00
# 2             Mode  150000000.0  2.177643e+08   115.00

# %%
out=df_rev
out
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44    190000000                     [{"id": 28, "name": "Action"}]
# ...         ...                                                ...
# 397    85000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 1744   30000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 698    70000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 717    60000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 714    65000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
#
#                                homepage      id  \
# 0           http://www.avatarmovie.com/   19995
# 25          http://www.titanicmovie.com     597
# ...

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.boxplot(out['budget'],showmeans=True, vert=1)
plt.title('Budget Box Plot')

plt.subplot(1, 3, 2)
plt.boxplot(out['revenue'],showmeans=True, vert=1)
plt.title('Revenue Box Plot')

plt.subplot(1, 3, 3)
plt.boxplot(out['runtime'],showmeans=True, vert=1)
plt.title('Runtime Box Plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# <b>Task 11:Identify and display the names of the movies along with their run times for those movies that have above average runtime, using the data from the previous task.

# %%
avg=out['runtime'].mean()
round(avg,2)
# Out:
# 118.72

# %%
above_avg_df=out[out['runtime']>avg]
above_avg_df[['title','runtime']]
# Out:
#                  title  runtime
# 0               Avatar    162.0
# 25             Titanic    194.0
# 16        The Avengers    143.0
# 28      Jurassic World    124.0
# 44           Furious 7    137.0
# ...                ...      ...
# 521       The Terminal    128.0
# 397   It's Complicated    121.0
# 1744        Knocked Up    129.0
# 717       Jack Reacher    130.0
# 714         Collateral    120.0
#
# [234 rows x 2 columns]

# %%
out.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'production_companies1', 'Genres1'],
#       dtype='object')
